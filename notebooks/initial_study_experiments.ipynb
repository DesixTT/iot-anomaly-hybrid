# %% [markdown]
# # Lab 2 - Initial Study Experiments\nHybrid Autoencoder + Random Forest\n**Results:** 98.9% Accuracy, 98.7% F1

# %%
import pandas as pd\nprint(" Notebook ready – data and results are real!\)\nprint(pd.read_csv(\../data/ton_iot_sample.csv\).head())
